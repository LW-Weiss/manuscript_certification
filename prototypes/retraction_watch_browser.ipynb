# %%
from retraction_database import RetractionDatabase

# %%
rd = RetractionDatabase("../retraction_watch.duckdb")
# rd.connect()
rd.head(10)
# Out:
#    Record ID                                              Title  \
# 0      66942  How does multidimensional R&D investment affec...
# 1      66941  Examining the effects of information and commu...
# 2      66940  Environmental concern in the era of digital fi...
# 3      66939  Does industrial up-gradation, environment regu...
# 4      66938  Do Higher Education and Financial Institutions...
# 5      66937  Assessing the management student's entrepreneu...
# 6      66936  Appraising and reacting to voluntary green beh...
# 7      66916  Potential Factors for Psychological Symptoms a...
# 8      66915  Prediction and Risk Assessment Models for Suba...
# 9      66914  Identification of lncRNA Biomarkers and LINC01...
#
#                                              Subject  \
# 0  (B/T) Business - Economics;(B/T) Business - Ma...
# 1  (B/T) Business - Economics;(B/T) Government;(B...
# 2  (B/T) Business - Economics;(B/T) Government;(E...
# ...

# %%
rd.query("SELECT * FROM retractions WHERE journal = 'Nature' LIMIT 5")
# Out:
#    Record ID                                              Title  \
# 0      66396  Transformation of primary human endothelial ce...
# 1      66100  Human fetal cerebellar cell atlas informs medu...
# 2      61011  A mechanism for the suppression of homologous ...
# 3      54402  Microbiome analyses of blood and tissues sugge...
# 4      54381  Pluripotency of mesenchymal stem cells derived...
#
#                                              Subject  \
# 0       (BLS) Biology - Cellular;(BLS) Microbiology;
# 1  (BLS) Biology - Cancer;(BLS) Biology - Cellula...
# 2             (BLS) Biology - Cancer;(BLS) Genetics;
# 3  (BLS) Biochemistry;(BLS) Biology - Cancer;(BLS...
# 4                          (BLS) Biology - Cellular;
#
#                                          Institution Journal  \
# 0  Department of Pathology, Department of Medicin...  Nature
# 1  Brain Tumor Center, Division of Experimental H...  Nature
# 2  The Lunenfeld-Tanenbaum Research Institute, Mo...  Nature
# ...

# %%
rd.query("SELECT * FROM retractions WHERE publisher = 'MDPI';")
# Out:
#      Record ID                                              Title  \
# 0        66542  Designing an ASR Corpus for the Albanian Language
# 1        66541  Palmitic Acid Impedes Extravillous Trophoblast...
# 2        66525  Mechanical Properties Study on Sandwich Compos...
# 3        66517  MicroRNA-21 Plays Multiple Oncometabolic Roles...
# 4        66516  MicroRNA-21 Plays Multiple Oncometabolic Roles...
# ..         ...                                                ...
# 383       7545  Advanced Glycation End-Products Enhance Lung C...
# 384       6269  RNA Interference Targeting Slug Increases Chol...
# 385       6268  Knockdown of Snail Sensitizes Pancreatic Cance...
# 386       6265              Flux Dynamics in Y358 Superconductors
# 387       1984  Synthesis and In Vitro Antimycobacterial Activ...
#
#                                                Subject  \
# 0                (B/T) Data Science;(SOC) Linguistics;
# 1    (BLS) Biology - Cellular;(BLS) Biology - Molec...
# ...

# %%
rd.search('epidemiology')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#       Record ID                                              Title  \
# 0         45983  Teaching epidemiology in the I.M. Sechenov Fir...
# 1         45984  Epidemiology as a prophilactic discipline in c...
# 2         28625  What we have learnt from the SARS epdemics in ...
# 3         19253  Glyphosate epidemiology expert panel review: a...
# 4         19252  Glyphosate epidemiology expert panel review: a...
# ...         ...                                                ...
# 1240      53752  Relation of aerobic activity to cognition and ...
# 1241      56974  Impact of Provision of Abdominal Aortic Calcif...
# 1242      53020  Pharmacotherapy for adults with overweight and...
# 1243      41581  Gradual emergence followed by exponential spre...
# 1244      35043  The diagnosis and management of suspected feta...
#
#                                                 Subject  \
# ...

# %%
S
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 S
#
# NameError: name 'S' is not defined
